# %%
import altair as alt
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_bcubcg_fall2022/main/data/building_inventory.csv")

# %%
data.head()
# Out:
#                        Agency Name  \
# 0  Department of Natural Resources
# 1  Department of Natural Resources
# 2  Department of Natural Resources
# 3  Department of Natural Resources
# 4  Department of Natural Resources
#
#                                      Location Name             Address  \
# 0  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 1  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 2  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 3  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 4  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
#
#       City  Zip code  County  Congress Dist Congressional Full Name  Rep Dist  \
# 0  Astoria     61501  Fulton             17            Cheri Bustos        93
# 1  Astoria     61501  Fulton             17            Cheri Bustos        93
# 2  Astoria     61501  Fulton             17            Cheri Bustos        93
# ...

# %%
Source_url = 'https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_bcubcg_fall2022/main/data/building_inventory.csv'

# %%
#myJekyllSaveDir = 'C:/Users/vishw/vishwa79.github.io/assets/json/'

# %%
scatter1 = alt.Chart(Source_url).mark_point().encode(
    x='mean(Square Footage):Q', # Q is for quantitative
    y='Bldg Status:N'
)
scatter1
# Out:
# alt.Chart(...)

# %% [markdown]
# The above scatter plot shows the relationship between mean sqaure footage and building status. I have considered quantitative encoding for square footage and nominal for building status. I have not used any specific colour scheme for the plot.The x axis ranges from 0 to 20,000. In progress buildings have most sqaure footage.

# %%
# command to save json to assest folder 
#scatter1.save(myJekyllSaveDir+'sqaurefootage_wrt_bldgstatus.json')

# %%
hist_alt = alt.Chart(Source_url).mark_bar().encode(
    alt.X("Agency Name:N" ),
    alt.Y("count()")
)
hist_alt
# Out:
# alt.Chart(...)

# %% [markdown]
# In the above graph we can see the frequency each agency. We have considered nominal encoding for agency name as it is categorical variable.We have not used any particular color scheme for this plot. Department of Natural Resources has the highest count of records which is nearly 3,250.

# %%
#hist_alt.save(myJekyllSaveDir+'agency_frequency.json')

# %%
selection = alt.selection_multi(fields=['Usage Description'], bind='legend')

chart1=alt.Chart(Source_url).mark_area().encode(
    alt.X('year(Year Constructed):T', axis=alt.Axis(domain=False, format='%Y', tickSize=0)),
    alt.Y('sum(Square Footage):Q', stack='center', axis=None),
    alt.Color('Usage Description:N', scale=alt.Scale(scheme='tableau20')),
    opacity=alt.condition(selection, alt.value(1), alt.value(0.2))
).add_selection(
    selection
)

# %%
chart1
# Out:
# alt.Chart(...)

# %% [markdown]
# In the above interactive graph we have plotted the Year Constructed on X axis and sum of square footage on Y-axis. The usage description is used as legend and the color is dependent on it. We have considered temporal enciding for  year constructed, quantitative for square footage and nominal for usage description.The color scheme of tableau20 is dependent on legend(usage description). When you click on any legend (usgae description) , the data for that particular selection is highlighted.

# %%
#chart1.save(myJekyllSaveDir+'usage_description.json')

# %%
selector = alt.selection_single(encodings=['x','y'])
heat_alt=alt.Chart(Source_url).mark_rect().encode(
    y='Usage Description:N',
    x='Agency Name:N',
    color='median(Square Footage):Q'
).add_selection(
    selector
)

line_alt = alt.Chart(Source_url).mark_line().encode(
    x=alt.X('year(Year Acquired):T', axis=alt.Axis(domain=False, tickSize=0)),
    y=alt.Y('mean(Square Footage):Q'),
    color=alt.Color('Bldg Status:N',
                    scale=alt.Scale(scheme='tableau20'))
).transform_filter(
    selector
)

# %%
dashboard = heat_alt.properties(width=300) | line_alt.properties(width=300)

# %%
dashboard
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# In the above graphs the first one is a heatmap that shows a relationship between Usage Description and Agency Name on Y-axis and X-axis respectively.We have considered nominal encoding for usage desciption and agency name while for square footage we have taken quantitative encoding. The color of heat map is represented by median of Square Footage. When we are selecting any value(tile) here accordingly the plot in the side line graph shows mean of square footage over Year Acquired for that particular usage description and agency name selection. In the second graph which is interactive we have also used building status for legend and define color. We have taken temporal encoding for year acquired , quantitative for square footage and nominal for building status.I have taken tableau20 to define color which is represented by building status.

# %%
#dashboard.save(myJekyllSaveDir+'heatmap_linechart.json')

# %% [markdown]
# Resources :
# - https://github.com/UIUC-iSchool-DataViz/is445_oauoag_fall2022/blob/main/week11/inClass_week11.ipynb
# - https://altair-viz.github.io/user_guide/encoding.html#encoding-data-types
# - https://altair-viz.github.io/
